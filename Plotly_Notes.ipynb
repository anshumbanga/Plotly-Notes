# %% [markdown]
# # Table of contents
#
# - Introduction to Plotly
# - Scatter plots
# - Line Charts
# - Bar Plot
# - Bubble plot
# - Box Plot
# - Histograms
# - Displot
# - Heatmap

# %% [markdown]
# Plotly is a versatile Python library for creating interactive data visualizations. It offers a wide range of chart types, including scatter plots, bar charts, and heatmaps, and enables users to customize their visualizations with ease. With support for both online and offline plotting, Plotly is widely used in data analysis, scientific research, and business intelligence applications due to its simplicity and effectiveness in conveying complex data insights.
#
# Plotly basically a graphing library
# It is a company from canada

# %% [markdown]
# - Until now we did visualisations using Matplotlib, Seaborn and pandas. All of them produce static image files.
# - Plotly creates interactive visualisations in the form of html files
# - drawback- can't work with live data source(only works on static data)(That means data change krne se graph change ni hoga)
# - Dash is used to create live data based dashboard

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import plotly.express as px 
import warnings
warnings.filterwarnings('ignore')

# %%
df = px.data.iris()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
# Scatterplot 



px.scatter(df, x='sepal_length', y='sepal_width', color='species', title='Sepal Length vs Width')
# Out:
# <div>                            <div id="1d79a82d-f6d8-4e7f-90b0-7eb61bc1ba40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d79a82d-f6d8-4e7f-90b0-7eb61bc1ba40")) {                    Plotly.newPlot(                        "1d79a82d-f6d8-4e7f-90b0-7eb61bc1ba40",                        [{"hovertemplate":"species=setosa<br>sepal_length=%{x}<br>sepal_width=%{y}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","orientation":"v","showlegend":true,"x":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"xaxis":"x","y":[3.5,3.0,3.2,3.1
# ...

# %% [markdown]
# Insights:
#
# - We can observe that the setosa species generally has smaller sepal width and length compared to the other two species.
# - Versicolor and virginica species have a wider range of sepal lengths and widths.

# %% [markdown]
# Purpose:
# - Scatter plots are used to visualize the relationship or association between two numerical variables.
#  - They help identify patterns, trends, correlations, and outliers in the data.

# %%
px.scatter(df, x='sepal_length', y='sepal_width', color='species')
# Out:
# <div>                            <div id="73e9153b-a7ea-40da-bc9d-0c0809233c6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73e9153b-a7ea-40da-bc9d-0c0809233c6d")) {                    Plotly.newPlot(                        "73e9153b-a7ea-40da-bc9d-0c0809233c6d",                        [{"hovertemplate":"species=setosa<br>sepal_length=%{x}<br>sepal_width=%{y}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","orientation":"v","showlegend":true,"x":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"xaxis":"x","y":[3.5,3.0,3.2,3.1
# ...

# %%
# size parameter

df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# size 

px.scatter(data_frame=df,x='tip',y='total_bill',size='size')
# add category color, for better understanding
# Out:
# <div>                            <div id="21c72a6a-0eb1-4828-bc85-3235500cc526" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21c72a6a-0eb1-4828-bc85-3235500cc526")) {                    Plotly.newPlot(                        "21c72a6a-0eb1-4828-bc85-3235500cc526",                        [{"hovertemplate":"tip=%{x}<br>total_bill=%{y}<br>size=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[2,3,3,2,4,4,2,4,2,2,2,4,2,4,2,2,3,3,3,3,2,2,2,4,2,4,2,2,2,2,2,4,2,4,2,3,3,3,3,3,3,2,2,2,4,2,2,4,3,2,2,2,4,2,4,2,4,2,2,4,2,2,2,4,3,3,2,1,2,2,2,3,2,2,2,2,2,4,2,2,2,2,1,2,2,4,2,2,2,2,2,2,2,2,2,4,2,2,2,2,2,2,3,2,2,2,2,2,2,2,2,1,3,2,3,2,4,2,2,4,2,2,2,2,2,6,2,2,2,3,2,2,2,2,2,2,2,2,2,2,2,6,5,6,2,2,3,2,2,2,2,2,3,4,4,5,6,4,2,4,4,2,3,2,2
# ...

# %%
#symbol

px.scatter(data_frame=df,x='tip',y='total_bill',symbol='size',color='time')
# Out:
# <div>                            <div id="98b9574f-f99f-4ebc-b70a-5609572936ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98b9574f-f99f-4ebc-b70a-5609572936ba")) {                    Plotly.newPlot(                        "98b9574f-f99f-4ebc-b70a-5609572936ba",                        [{"hovertemplate":"time=Dinner<br>size=2<br>tip=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Dinner, 2","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner, 2","orientation":"v","showlegend":true,"x":[1.01,3.31,2.0,1.96,3.23,1.71,1.57,3.02,3.92,4.08,2.75,2.23,3.18,2.0,2.0,4.3,3.0,1.45,3.0,3.27,2.54,3.06,1.32,3.0,5.0,3.0,2.5,2.6,1.56,3.51,1.5,1.76,3.21,2.0,1.98,2.47,2.01,2.09,1.97,3.14,5.0,2.2,1.25,3.08,3.0,3.5,1.0,4.3,3.25,4.0,
# ...

# %%
# hover 
px.scatter(data_frame=df,x='tip',y='total_bill',symbol='size',color='time', hover_name='sex', hover_data=['size', 'day', 'time'])
# Out:
# <div>                            <div id="2e49494b-1806-48c0-ba95-caf5736ceb36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e49494b-1806-48c0-ba95-caf5736ceb36")) {                    Plotly.newPlot(                        "2e49494b-1806-48c0-ba95-caf5736ceb36",                        [{"customdata":[[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sat","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinner"],[2,"Sun","Dinne
# ...

# %%
# trendline 
# rehne denge 
px.scatter(data_frame=df,x='tip',y='total_bill',symbol='size',color='time',trendline='ols')
# Out:
# <div>                            <div id="3ae9d4d4-fd11-4248-a193-4645c93d8ec1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ae9d4d4-fd11-4248-a193-4645c93d8ec1")) {                    Plotly.newPlot(                        "3ae9d4d4-fd11-4248-a193-4645c93d8ec1",                        [{"hovertemplate":"time=Dinner<br>size=2<br>tip=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Dinner, 2","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner, 2","orientation":"v","showlegend":true,"x":[1.01,3.31,2.0,1.96,3.23,1.71,1.57,3.02,3.92,4.08,2.75,2.23,3.18,2.0,2.0,4.3,3.0,1.45,3.0,3.27,2.54,3.06,1.32,3.0,5.0,3.0,2.5,2.6,1.56,3.51,1.5,1.76,3.21,2.0,1.98,2.47,2.01,2.09,1.97,3.14,5.0,2.2,1.25,3.08,3.0,3.5,1.0,4.3,3.25,4.0,
# ...

# %% [markdown]
# # line plot
#
# Purpose:
#
# - Line plots are commonly used to visualize trends or patterns in data over time or another ordered dimension.
# - They are effective for showing changes in a variable's value continuously or sequentially.
# (time series analysis)
#
# Components:
#
# - In a line plot, data points are represented by markers (dots), and the markers are connected by lines to show the sequence or progression of the data.
# - Each data point typically represents an observation at a specific point in time or order.

# %%
df = px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
# line plot 
px.line(df, x='year', y='lifeExp', color='country', title='Life Expectancy Over Time')
# Out:
# <div>                            <div id="30e46866-c25a-4493-8f09-affe45bb3802" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30e46866-c25a-4493-8f09-affe45bb3802")) {                    Plotly.newPlot(                        "30e46866-c25a-4493-8f09-affe45bb3802",                        [{"hovertemplate":"country=Afghanistan<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[28.801,30.332,31.997,34.02,36.088,38.438,39.854,40.822,41.674,41.76300000000001,42.129,43.828],"yaxis":"y","type":"scattergl"},{"hovertemplate":"cou
# ...

# %%
# for better understanding 
temp_data = df[df['country'].isin(["India","Pakistan","China"])]

# %%
temp_data
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
px.line(temp_data,x='year',y='lifeExp',color='country')
# Out:
# <div>                            <div id="69b4b1d3-bda2-4b27-bd51-9bc7941fa659" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69b4b1d3-bda2-4b27-bd51-9bc7941fa659")) {                    Plotly.newPlot(                        "69b4b1d3-bda2-4b27-bd51-9bc7941fa659",                        [{"hovertemplate":"country=China<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=
# ...

# %%
df[df.country=='India']
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
px.line(df[df.country=='India'],x='year',y='lifeExp')
# Out:
# <div>                            <div id="ec8b1cff-54fa-42f5-9cd0-2977fc0d1069" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec8b1cff-54fa-42f5-9cd0-2977fc0d1069")) {                    Plotly.newPlot(                        "ec8b1cff-54fa-42f5-9cd0-2977fc0d1069",                        [{"hovertemplate":"year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[37.37300000000001,40.249,43.605,47.19300000000001,50.651,54.208,56.596,58.553,60.223,61.765,62.879,64.69800000000001],"yaxis":"y","type":"scatter"}],                        {
# ...

# %%
temp_df = df[df.continent=='Europe']

# %%
temp_df
# Out:
#              country continent  year  lifeExp       pop     gdpPercap  \
# 12           Albania    Europe  1952   55.230   1282697   1601.056136
# 13           Albania    Europe  1957   59.280   1476505   1942.284244
# 14           Albania    Europe  1962   64.820   1728137   2312.888958
# 15           Albania    Europe  1967   66.220   1984060   2760.196931
# 16           Albania    Europe  1972   67.690   2263554   3313.422188
# ...              ...       ...   ...      ...       ...           ...
# 1603  United Kingdom    Europe  1987   75.007  56981620  21664.787670
# 1604  United Kingdom    Europe  1992   76.420  57866349  22705.092540
# 1605  United Kingdom    Europe  1997   77.218  58808266  26074.531360
# 1606  United Kingdom    Europe  2002   78.471  59912431  29478.999190
# 1607  United Kingdom    Europe  2007   79.425  60776238  33203.261280
#
#      iso_alpha  iso_num
# 12         ALB        8
# 13         ALB        8
# 14         ALB        8
# 15         ALB        8
# ...

# %%
px.line(temp_df,x='year',y='lifeExp',color='country')
# Out:
# <div>                            <div id="4aae6574-1805-4dd3-b308-8ecfefddb22e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aae6574-1805-4dd3-b308-8ecfefddb22e")) {                    Plotly.newPlot(                        "4aae6574-1805-4dd3-b308-8ecfefddb22e",                        [{"hovertemplate":"country=Albania<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Albania","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Albania","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[55.23,59.28,64.82,66.22,67.69,68.93,70.42,72.0,71.581,72.95,75.65100000000002,76.423],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=
# ...

# %%
# for color paramter
df[df['country'].isin(['India','Germany','Zimbabwe'])]
# Out:
#        country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 564    Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565    Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566    Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567    Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568    Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569    Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570    Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571    Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572    Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573    Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574    Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# ...

# %%
# color parameter

px.line(df[df['country'].isin(['India','Germany','Zimbabwe'])],x='year',y='lifeExp',color='continent')
# Out:
# <div>                            <div id="e33dcc72-398c-4a16-8057-abe8b30d49cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e33dcc72-398c-4a16-8057-abe8b30d49cb")) {                    Plotly.newPlot(                        "e33dcc72-398c-4a16-8057-abe8b30d49cb",                        [{"hovertemplate":"continent=Europe<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Europe","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[67.5,69.1,70.3,70.8,71.0,72.5,73.8,74.847,76.07,77.34,78.67,79.406],"yaxis":"y","type":"scatter"},{"hovertemplate":"continent=Asia<br>year=%{x}
# ...

# %%
# title 
px.line(df[df['country'].isin(['India','Germany','Zimbabwe'])],x='year',y='lifeExp',color='continent',title='Life exp over time')
# Out:
# <div>                            <div id="2e3401ed-0170-42e8-a9e2-570ce7ceae28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e3401ed-0170-42e8-a9e2-570ce7ceae28")) {                    Plotly.newPlot(                        "2e3401ed-0170-42e8-a9e2-570ce7ceae28",                        [{"hovertemplate":"continent=Europe<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Europe","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[67.5,69.1,70.3,70.8,71.0,72.5,73.8,74.847,76.07,77.34,78.67,79.406],"yaxis":"y","type":"scatter"},{"hovertemplate":"continent=Asia<br>year=%{x}
# ...

# %%
# labels 
#labels={'year': 'Year', 'lifeExp': 'Life Expectancy'}

px.line(df[df['country'].isin(['India','Germany','Zimbabwe'])],x='year',y='lifeExp',color='continent',title='Life exp over time',labels={'year': 'Year', 'lifeExp': 'Life Expectancy'})
# Out:
# <div>                            <div id="6d48f6da-0cc6-4cfd-8af9-e10f6932a1ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d48f6da-0cc6-4cfd-8af9-e10f6932a1ef")) {                    Plotly.newPlot(                        "6d48f6da-0cc6-4cfd-8af9-e10f6932a1ef",                        [{"hovertemplate":"continent=Europe<br>Year=%{x}<br>Life Expectancy=%{y}<extra></extra>","legendgroup":"Europe","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe","orientation":"v","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[67.5,69.1,70.3,70.8,71.0,72.5,73.8,74.847,76.07,77.34,78.67,79.406],"yaxis":"y","type":"scatter"},{"hovertemplate":"continent=Asia<br>Y
# ...

# %% [markdown]
# Certainly! A bar plot is a type of data visualization that uses rectangular bars to represent the frequency, count, or proportion of categorical data. In Plotly Express (px), you can create bar plots using the px.bar() function. Here's some information about bar plots in Plotly Express:
#
# **Purpose:**
#
# - Bar plots are commonly used to compare the values of categorical variables or to display the distribution of a categorical variable.
# - They are effective for visualizing the frequency or proportion of different categories within a dataset.
#
#
# **Components:**
#
# - In a bar plot, each bar represents a category, and the height (or length) of the bar corresponds to the frequency, count, or proportion of that category.
# - The bars are typically arranged along the x-axis, with the category labels displayed on the y-axis.

# %%
# barplot

df =sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.bar(df, x='day', y='total_bill')
# Out:
# <div>                            <div id="7e21a018-bda5-47e3-b523-5c6a515f53f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e21a018-bda5-47e3-b523-5c6a515f53f0")) {                    Plotly.newPlot(                        "7e21a018-bda5-47e3-b523-5c6a515f53f0",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat"
# ...

# %% [markdown]
# By default, Plotly Express's px.bar() function aggregates data using the sum for numerical variables when plotting bar plots. If you want to display the average instead, you need to perform the aggregation yourself before passing the data to Plotly Express.

# %%
# added reset index to make it a dataframe

df_temp = df.groupby('day')['total_bill'].mean().reset_index()

# %%
df_temp
# Out:
#     day  total_bill
# 0  Thur   17.682742
# 1   Fri   17.151579
# 2   Sat   20.441379
# 3   Sun   21.410000

# %%
px.bar(df_temp, x='day', y='total_bill')
# Out:
# <div>                            <div id="34e26cda-b640-40ca-bd25-bd73f3cd7728" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34e26cda-b640-40ca-bd25-bd73f3cd7728")) {                    Plotly.newPlot(                        "34e26cda-b640-40ca-bd25-bd73f3cd7728",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Thur","Fri","Sat","Sun"],"xaxis":"x","y":[17.682741935483868,17.15157894736842,20.44137931034483,21.41],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dco
# ...

# %%
#title

px.bar(df_temp, x='day', y='total_bill',title="Average total bill of the day")
# Out:
# <div>                            <div id="dd869c1b-f8cc-4773-9728-57a13e98c875" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd869c1b-f8cc-4773-9728-57a13e98c875")) {                    Plotly.newPlot(                        "dd869c1b-f8cc-4773-9728-57a13e98c875",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Thur","Fri","Sat","Sun"],"xaxis":"x","y":[17.682741935483868,17.15157894736842,20.44137931034483,21.41],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dco
# ...

# %%
# color 

px.bar(df_temp, x='day', y='total_bill',title="Average total bill of the day",color='day')
# Out:
# <div>                            <div id="f8e9ebfa-9864-43fb-996c-2718ce28aaea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8e9ebfa-9864-43fb-996c-2718ce28aaea")) {                    Plotly.newPlot(                        "f8e9ebfa-9864-43fb-996c-2718ce28aaea",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Thur","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Thur","offsetgroup":"Thur","orientation":"v","showlegend":true,"textposition":"auto","x":["Thur"],"xaxis":"x","y":[17.682741935483868],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Fri","marker":{"color":"#EF553B","patt
# ...

# %%
# barmode='group'
# group , overlay , or relative
px.bar(df_temp, x='day', y='total_bill',title="Average total bill of the day",color='day', barmode='group')

# not better representation
# Out:
# <div>                            <div id="404811ff-45c8-4d73-8908-713d5060a1f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("404811ff-45c8-4d73-8908-713d5060a1f5")) {                    Plotly.newPlot(                        "404811ff-45c8-4d73-8908-713d5060a1f5",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Thur","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Thur","offsetgroup":"Thur","orientation":"v","showlegend":true,"textposition":"auto","x":["Thur"],"xaxis":"x","y":[17.682741935483868],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Fri","marker":{"color":"#EF553B","patt
# ...

# %%
px.bar(df, x='day', y='total_bill', color='sex',barmode='group')
# Out:
# <div>                            <div id="627975e7-b324-40db-8da3-c9cec4cf2f76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("627975e7-b324-40db-8da3-c9cec4cf2f76")) {                    Plotly.newPlot(                        "627975e7-b324-40db-8da3-c9cec4cf2f76",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri","Fri","Sat","Sat","Sat","S
# ...

# %%
px.bar(df, x='day', y='total_bill', color='sex',barmode='relative')
# Out:
# <div>                            <div id="75dcfdb1-9a08-4dd8-b58d-cbf1344b594f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75dcfdb1-9a08-4dd8-b58d-cbf1344b594f")) {                    Plotly.newPlot(                        "75dcfdb1-9a08-4dd8-b58d-cbf1344b594f",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri","Fri","Sat","Sat","Sat","S
# ...

# %%
px.bar(df, x='day', y='total_bill', color='sex',barmode='overlay')
# Out:
# <div>                            <div id="b71c0b9b-148e-4669-8602-94800dfdec23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b71c0b9b-148e-4669-8602-94800dfdec23")) {                    Plotly.newPlot(                        "b71c0b9b-148e-4669-8602-94800dfdec23",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri","Fri","Sat",
# ...

# %% [markdown]
# - reference, jab humne hist mein hue sex pass kia tha kuch aisa hi aya tha

# %%
# labels labels={'day': 'Day of the Week', 'total_bill': 'Total Bill'}

px.bar(df, x='day', y='total_bill', color='sex',barmode='overlay', labels={'day': 'Day of the Week', 'total_bill': 'Total Bill'})
# Out:
# <div>                            <div id="ae406b42-318f-437e-b467-7b85d651e020" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae406b42-318f-437e-b467-7b85d651e020")) {                    Plotly.newPlot(                        "ae406b42-318f-437e-b467-7b85d651e020",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>Day of the Week=%{x}<br>Total Bill=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri",
# ...

# %%
# title 
px.bar(df, x='day', y='total_bill', color='sex',barmode='overlay', labels={'day': 'Day of the Week', 'total_bill': 'Total Bill'}, title='Total bill over weeks')
# Out:
# <div>                            <div id="9ea7e6ab-af36-4b5f-9f4b-2230e5a39b6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ea7e6ab-af36-4b5f-9f4b-2230e5a39b6f")) {                    Plotly.newPlot(                        "9ea7e6ab-af36-4b5f-9f4b-2230e5a39b6f",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>Day of the Week=%{x}<br>Total Bill=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri",
# ...

# %%
# template='plotly',
#'ggplot2', 'seaborn', 'simple_white', 'plotly',
        # 'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
        # 'ygridoff', 'gridon', 'none'

px.bar(df, x='day', y='total_bill', color='sex',barmode='overlay', template='simple_white')
# Out:
# <div>                            <div id="7b1dfb14-fb01-4a8e-a03f-6d1c716f6b4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b1dfb14-fb01-4a8e-a03f-6d1c716f6b4f")) {                    Plotly.newPlot(                        "7b1dfb14-fb01-4a8e-a03f-6d1c716f6b4f",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#1F77B4","opacity":0.5,"pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri","Fri","Sat",
# ...
